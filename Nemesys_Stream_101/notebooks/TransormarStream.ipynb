# %% [markdown]
# # Simulação da Carga para Camadas Gold e Platinnum
# ## Configuração do ambiente

# %%
import time
from datetime import date, timedelta
from delta import *
from os import path
from pyspark.sql.functions import translate, to_timestamp, date_format,concat_ws, col
from pyspark.sql.types import StringType, DateType, StructType, IntegerType, LongType

# %%
spark.conf.set(f'fs.azure.account.auth.type.{STORAGE_ACCOUNT}.dfs.core.windows.net', 'OAuth')
spark.conf.set(f'fs.azure.account.oauth.provider.type.{STORAGE_ACCOUNT}.dfs.core.windows.net',  'org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider')
spark.conf.set(f'fs.azure.account.oauth2.client.id.{STORAGE_ACCOUNT}.dfs.core.windows.net', APPLICATION_ID)
spark.conf.set(f'fs.azure.account.oauth2.client.secret.{STORAGE_ACCOUNT}.dfs.core.windows.net', PASSWORD)
spark.conf.set(f'fs.azure.account.oauth2.client.endpoint.{STORAGE_ACCOUNT}.dfs.core.windows.net', f'https://login.microsoftonline.com/{DIRECTORY_ID}/oauth2/token')

# %% [markdown]
# Define os caminhos para acessar as camadas bronze, silver e gold além de definir o schema para a camada gold. Caso esta ainda não exista, criar a Delta Table para a camada

# %%
bronze_table = f'abfss://{LAKEHOUSE}@{STORAGE_ACCOUNT}.dfs.core.windows.net/bronze/{TOPIC}'
silver_table = f'abfss://{LAKEHOUSE}@{STORAGE_ACCOUNT}.dfs.core.windows.net/silver/{TOPIC}'
gold_table = f'abfss://{LAKEHOUSE}@{STORAGE_ACCOUNT}.dfs.core.windows.net/gold/{TOPIC}'
checkpoint_path = f'abfss://{LAKEHOUSE}@{STORAGE_ACCOUNT}.dfs.core.windows.net/checkpoint/silver/delta/{TOPIC}'

if not DeltaTable.isDeltaTable(spark, silver_table):
    print(f'Criar tabela {TOPIC}')
    if TOPIC == 'audit':
        schema = (StructType()
            .add('_id', StringType())
            .add('ano', IntegerType())
            .add('mes', IntegerType())
            .add('dia', IntegerType())
            .add('hora', IntegerType())
            .add('minuto', IntegerType())                  
            .add('idacao', StringType())
            .add('idproduto', StringType())
            .add('idservico', StringType())
            .add('idatividade', StringType())
            .add('payload', StringType())
            .add('porta', StringType())
            .add('idusuario', StringType())
            .add('nomeusuario', StringType())
            .add('localizador_tipo', StringType())
            .add('localizador', StringType())
            .add('ip', StringType())
            .add('data_fim', StringType())
            .add('data_inicio', StringType())
            .add('idcliente', StringType())
            .add('cliente', StringType())
            .add('idplataforma', StringType())
            .add('plataforma', StringType())
            .add('data', StringType())
            .add('horario', StringType())
            .add('data_criacao', StringType())
            .add('duracao', StringType())
            .add('produto', StringType())
            .add('atividade', StringType())
            .add('acao', StringType())
            .add('servico', StringType())
        )
        emptyDF = spark.createDataFrame(spark.sparkContext.emptyRDD(), schema)
        emptyDF.write.format('delta').mode('overwrite').partitionBy('ano', 'mes', 'dia').save(silver_table)        
    else:
        schema = (StructType()
            .add('_id', StringType())
            .add('nome', StringType())
        )    
        emptyDF = spark.createDataFrame(spark.sparkContext.emptyRDD(), schema)
        emptyDF.write.format('delta').mode('overwrite').save(silver_table)
    

deltaTable = DeltaTable.forPath(spark, silver_table)

# %%
def carregar_tabela(tabela, tier='bronze'):
#     df = spark.read.format('delta').load(path.join(LAKEHOUSE, 'bronze', tabela))
    df = spark.read.format('delta').load(f'abfss://{LAKEHOUSE}@{STORAGE_ACCOUNT}.dfs.core.windows.net/{tier}/{tabela}') \

    df.createOrReplaceTempView(tabela)
    return df

def config_upsert(delta):
    def upsertToDelta(microbatchdf, batchId):
        delta.alias("t").merge(
          microbatchdf.alias("s"),
          "s._id = t._id") \
        .whenMatchedUpdateAll() \
        .whenNotMatchedInsertAll() \
        .execute()
        print(f'Exportadas {microbatchdf.count()} linhas')
        
    return upsertToDelta

# %%
# %%time
# df = (
#     spark
#     .readStream
#     .format('delta')
#     .option('startingOffsets', 'latest')
#     .load(bronze_table)
#     .withColumn('data_criacao', to_timestamp('data_criacao'))
#     .withColumn('ano', date_format('data_criacao', 'yyyy').cast(IntegerType()))
#     .withColumn('mes', date_format('data_criacao', 'MM').cast(IntegerType()))
#     .withColumn('dia', date_format('data_criacao', 'dd').cast(IntegerType()))
#     .withColumn('hora', date_format('data_criacao', 'HH').cast(IntegerType()))
#     .withColumn('minuto', date_format('data_criacao', 'mm').cast(IntegerType()))    
#     .writeStream
#     .format('delta')
#     .foreachBatch(config_upsert(deltaTable))
#     .outputMode('update')
#     .option('checkpointLocation', checkpoint_path)
#     .trigger(once=True)
#     .start()
#     .awaitTermination()
# )

# 29140896
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 7.15 µs

# %%
# %%time
df_bronze = carregar_tabela(TOPIC, 'bronze')
# df_bronze.toPandas()
# Out:
# CPU times: user 1.7 ms, sys: 1.61 ms, total: 3.31 ms
# Wall time: 2.35 s

# %%
# %%time
df_silver = carregar_tabela(TOPIC, 'silver')
# df_silver.toPandas()
# Out:
# CPU times: user 1.38 ms, sys: 1.49 ms, total: 2.87 ms
# Wall time: 192 ms

# %%
# %%time
print(f'Bronze: {df_bronze.count()}')
print(f'Silver: {df_silver.count()}')

# 07:07
# Bronze: 28909691
# Silver: 28909691

# 11:00
# Bronze: 28909801
# Silver: 28909801

# Bronze: 29140896
# Silver: 29140896

# Bronze: 29189458
# Silver: 29189289

# 29.730.484 9:27
# 29.741.472
# 29.919.115
# 29.946.055
# Out:
# Bronze: 29946878
# Silver: 29946878
# CPU times: user 7.43 ms, sys: 4.54 ms, total: 12 ms
# Wall time: 1min 9s

# %% [markdown]
# ### Processar GOLD

# %%
df_silver.printSchema()
df_silver.createOrReplaceTempView("evento")
# Out:
# root
#  |-- _id: string (nullable = true)
#  |-- ano: integer (nullable = true)
#  |-- mes: integer (nullable = true)
#  |-- dia: integer (nullable = true)
#  |-- hora: integer (nullable = true)
#  |-- minuto: integer (nullable = true)
#  |-- idacao: string (nullable = true)
#  |-- idproduto: string (nullable = true)
#  |-- idservico: string (nullable = true)
#  |-- idatividade: string (nullable = true)
#  |-- payload: string (nullable = true)
#  |-- porta: string (nullable = true)
#  |-- idusuario: string (nullable = true)
#  |-- nomeusuario: string (nullable = true)
#  |-- localizador_tipo: string (nullable = true)
#  |-- localizador: string (nullable = true)
#  |-- ip: string (nullable = true)
#  |-- data_fim: string (nullable = true)
#  |-- data_inicio: string (nullable = true)
#  |-- idcliente: string (nullable = true)
#  |-- cliente: string (nullable = true)
#  |-- idplataforma: string (nullable = true)
#  |-- plataforma: string (nullable = true)
#  |-- data: string (nullable = true)
#  |-- horario: string (nullable = true)
#  |-- data_criacao: string (nullable = true)
#  |-- duracao: string (nullable = true)
#  |-- produto: string (nullable = true)
#  |-- atividade: string (nullable = true)
#  |-- acao: string (nullable = true)
#  |-- servico: string (nullable = true)

# %%
hoje = date.today()
ontem = hoje - timedelta(1)
print(f'Hoje..: {hoje}')
print(f'Ontem.: {ontem}')
# Out:
# Hoje..: 2022-03-21
# Ontem.: 2022-03-20

# %%
if not DeltaTable.isDeltaTable(spark, gold_table):
    print(f'Criar tabela {TOPIC}')
    schema = (StructType()
        .add('ano', IntegerType())
        .add('mes', IntegerType())
        .add('dia', IntegerType())
        .add('hora', IntegerType())
        .add('minuto', IntegerType())                  
        .add('idplataforma', StringType())
        .add('plataforma', StringType())
        .add('idcliente', StringType())
        .add('cliente', StringType())
        .add('idservico', StringType())
        .add('servico', StringType())
        .add('idproduto', StringType())
        .add('produto', StringType())              
        .add('idatividade', StringType())
        .add('atividade', StringType())
        .add('idacao', StringType())
        .add('acao', StringType())                      
        .add('idusuario', StringType())
        .add('usuario', StringType())
        .add('quantidade', LongType())              
    )
    emptyDF = spark.createDataFrame(spark.sparkContext.emptyRDD(), schema)
    emptyDF.write.format('delta').mode('overwrite').partitionBy('ano', 'mes', 'dia').save(gold_table)        


delta_gold = DeltaTable.forPath(spark, gold_table)
# Out:
# Criar tabela audit

# %%
df_gold = spark.read.format('delta').load(gold_table)
df_gold.printSchema()
# Out:
# root
#  |-- ano: integer (nullable = true)
#  |-- mes: integer (nullable = true)
#  |-- dia: integer (nullable = true)
#  |-- hora: integer (nullable = true)
#  |-- minuto: integer (nullable = true)
#  |-- idplataforma: string (nullable = true)
#  |-- plataforma: string (nullable = true)
#  |-- idcliente: string (nullable = true)
#  |-- cliente: string (nullable = true)
#  |-- idservico: string (nullable = true)
#  |-- servico: string (nullable = true)
#  |-- idproduto: string (nullable = true)
#  |-- produto: string (nullable = true)
#  |-- idatividade: string (nullable = true)
#  |-- atividade: string (nullable = true)
#  |-- idacao: string (nullable = true)
#  |-- acao: string (nullable = true)
#  |-- idusuario: string (nullable = true)
#  |-- usuario: string (nullable = true)
#  |-- quantidade: long (nullable = true)

# %%
# %%time
df = spark.sql(f'''
select
    ano,
    mes,
    dia,
    hora,
    minuto,
    idplataforma,
    idcliente,
    idservico,
    idproduto,    
    idatividade,
    idacao,
    idusuario,
    count(*) as quantidade
from evento
-- where ano in ({hoje.year}, {ontem.year})
--  and mes in ({hoje.month}, {ontem.month})
--  and dia in ({hoje.day}, {ontem.day})
group by
    ano,
    mes,
    dia,
    hora,
    minuto,
    idplataforma,
    idcliente,
    idservico,
    idproduto,  
    idatividade,
    idacao,
    idusuario
order by
    ano,
    mes,
    dia,
    hora,
    minuto,
    idplataforma,
    idcliente,
    idservico,
    idproduto,  
    idatividade,
    idacao,
    idusuario
''')

df.createOrReplaceTempView('estatistica')

df.toPandas()
# Out:
# CPU times: user 7.79 s, sys: 599 ms, total: 8.39 s
# Wall time: 1min 33s
#           ano  mes  dia  hora  minuto              idplataforma  \
# 0        2020    2   27    21       8  5e455d76ce7d620f184d443d
# 1        2020    2   27    21       8  5e455d76ce7d620f184d443d
# 2        2020    2   27    21       8  5e455d76ce7d620f184d443d
# 3        2020    2   27    21       8  5e455d76ce7d620f184d443d
# 4        2020    2   27    21       9  5e455d76ce7d620f184d443d
# ...       ...  ...  ...   ...     ...                       ...
# 1131653  2022    3   20    20       8  5e455d76ce7d620f184d443d
# 1131654  2022    3   20    20      10  5e455d76ce7d620f184d443d
# 1131655  2022    3   20    20      11  5e455d76ce7d620f184d443d
# 1131656  2022    3   20    20      13  5e455d76ce7d620f184d443d
# 1131657  2022    3   20    20      16  5e455d76ce7d620f184d443d
#
#                         idcliente                 idservico  \
# 0        5e455cb8ce7d620f184d443c  5e455ed9ce7d620f184d4446
# 1        5e455cb8ce7d620f184d443c  5e455ed9ce7d620f184d4446
# 2        5e455cb8ce7d620f184d443c  5e455ed9ce7d620f184d4446
# 3        5e455cb8ce7d620f184d443c  5e455ed9ce7d620f184d4446
# 4        5e455cb8ce7d620f184d443c  5e455ed9ce7d620f184d4446
# ...                           ...                       ...
# 1131653  5e455cb8ce7d620f184d443c  5e455ed9ce7d620f184d4446
# 1131654  5e455cb8ce7d620f184d443c  5e455ed9ce7d620f184d4446
# 1131655  5e455cb8ce7d620f184d443c  5e455ed9ce7d620f184d4446
# 1131656  5e455cb8ce7d620f184d443c  5e455ed9ce7d620f184d4446
# 1131657  5e455cb8ce7d620f184d443c  5e455ed9ce7d620f184d4446
#
#                         idproduto               idatividade  \
# 0        5e455e09ce7d620f184d4442  5e455f83ce7d620f184d444b
# 1        5e455e09ce7d620f184d4442  5e455f83ce7d620f184d444b
# 2        5e455e09ce7d620f184d4442  5e455f83ce7d620f184d444b
# 3        5e455e09ce7d620f184d4442  5e455f83ce7d620f184d444b
# 4        5e455e09ce7d620f184d4442  5e455f83ce7d620f184d444b
# ...                           ...                       ...
# 1131653  5e455e09ce7d620f184d4442  5e455f66ce7d620f184d4449
# 1131654  5e455e09ce7d620f184d4442  5e455f66ce7d620f184d4449
# 1131655  5e455e09ce7d620f184d4442  5e455f66ce7d620f184d4449
# 1131656  5e455e09ce7d620f184d4442  5e455f66ce7d620f184d4449
# 1131657  5e455e09ce7d620f184d4442  5e455f66ce7d620f184d4449
#
#                            idacao                 idusuario  quantidade
# 0        5e4c555ad52d1c182dc1cb8f  5b563a26a72acc7d1e169176           1
# 1        5e4c555ad52d1c182dc1cb8f  5e3af6682ec70521bd72882b          31
# 2        5e4c555ad52d1c182dc1cb8f  5e42c695982952ebca48ae10           8
# 3        5e4c555ad52d1c182dc1cb8f  5e5017126fa8736e01b191a3           2
# 4        5e4c555ad52d1c182dc1cb8f  5b563a26a72acc7d1e169176           3
# ...                           ...                       ...         ...
# 1131653  5e4c555ad52d1c182dc1cb90  6101c33703b5809d7d5ef127           1
# 1131654  5e4c555ad52d1c182dc1cb90  6101c33703b5809d7d5ef127           2
# 1131655  5e4c555ad52d1c182dc1cb90  6101c33703b5809d7d5ef127           1
# 1131656  5e4c555ad52d1c182dc1cb90  6101c33703b5809d7d5ef127           1
# 1131657  5e4c555ad52d1c182dc1cb90  6101c33703b5809d7d5ef127           2
#
# [1131658 rows x 13 columns]

# %% [markdown]
# #### Gerar tabelas de apoio

# %%
# %%time
df_plataforma = spark.sql('select distinct idplataforma, plataforma from evento')
df_plataforma.createOrReplaceTempView('plataforma')
df_cliente = spark.sql('select distinct idcliente, cliente from evento')
df_cliente.createOrReplaceTempView('cliente')
df_servico = spark.sql('select distinct idservico, servico from evento')
df_servico.createOrReplaceTempView('servico')
df_produto = spark.sql('select distinct idproduto, produto from evento')
df_produto.createOrReplaceTempView('produto')
df_atividade = spark.sql('select distinct idatividade, atividade from evento')
df_atividade.createOrReplaceTempView('atividade')
df_acao = spark.sql('select distinct idacao, acao from evento')
df_acao.createOrReplaceTempView('acao')
# Out:
# CPU times: user 2.45 ms, sys: 1.31 ms, total: 3.76 ms
# Wall time: 55.1 ms

# %%
df_usuario = spark.sql('''
select distinct 
    idusuario, 
    nomeusuario as usuario 
from evento 
order by 1
''')
df_usuario = df_usuario.dropDuplicates(['idusuario'])
df_usuario.createOrReplaceTempView('usuario')

df_usuario.toPandas()
# Out:
#                      idusuario                            usuario
# 0     5b5639a3a72acc7d1e169175                      Bruno Aurelio
# 1     5b563a26a72acc7d1e169176                              admin
# 2     5b9ab33a00d165923ca5beee           5b9ab33a00d165923ca5beee
# 3     5de944fda1e187078a73875f               Bianca A de Oliveira
# 4     5e260884ec3807463e32afa3                   Administrador BF
# ...                        ...                                ...
# 1403  622f419653ba83a25cb1ffcc                          Comercial
# 1404  6233338ad8b02d963be4208a  BARBARA LETICIA PASSOS DOS SANTOS
# 1405  6233474190f10ddf4ccdccf0                             fabioc
# 1406  6234a2f59cf744683094de60   JESSICA ARIANE OLIVEIRA MARCIANO
# 1407  6235b2769c9e723ba345a468               WALTER DA CRUZ FILHO
#
# [1408 rows x 2 columns]

# %%
spark.sql('''
select *
from usuario
where idusuario = "5b563a26a72acc7d1e169176"
''').toPandas()
# Out:
#                   idusuario usuario
# 0  5b563a26a72acc7d1e169176   admin

# %%
# %%time
df = spark.sql('''
select
    e.ano,
    e.mes,
    e.dia,
    e.hora,
    e.minuto,
    e.idplataforma,
    p.plataforma,
    e.idcliente,
    c.cliente,
    e.idservico,
    s.servico,
    e.idproduto,
    pd.produto,
    e.idatividade,
    a.atividade,
    e.idacao,
    ac.acao,
    e.idusuario,
    u.usuario,
    e.quantidade
from estatistica e
    inner join plataforma p on p.idplataforma = e.idplataforma
    inner join cliente c on c.idcliente = e.idcliente
    inner join servico s on s.idservico = e.idservico
    inner join produto pd on pd.idproduto = e.idproduto
    inner join atividade a on a.idatividade = e.idatividade
    inner join acao ac on ac.idacao = e.idacao
    inner join usuario u on u.idusuario = e.idusuario
order by
    e.ano,
    e.mes,
    e.dia,
    e.hora,
    e.minuto,
    e.idplataforma,
    e.idcliente,
    e.idservico,
    e.idproduto,    
    e.idatividade,
    e.idacao,
    e.idusuario,
    e.quantidade    
''')
df.printSchema()
# Out:
# root
#  |-- ano: integer (nullable = true)
#  |-- mes: integer (nullable = true)
#  |-- dia: integer (nullable = true)
#  |-- hora: integer (nullable = true)
#  |-- minuto: integer (nullable = true)
#  |-- idplataforma: string (nullable = true)
#  |-- plataforma: string (nullable = true)
#  |-- idcliente: string (nullable = true)
#  |-- cliente: string (nullable = true)
#  |-- idservico: string (nullable = true)
#  |-- servico: string (nullable = true)
#  |-- idproduto: string (nullable = true)
#  |-- produto: string (nullable = true)
#  |-- idatividade: string (nullable = true)
#  |-- atividade: string (nullable = true)
#  |-- idacao: string (nullable = true)
#  |-- acao: string (nullable = true)
#  |-- idusuario: string (nullable = true)
#  |-- usuario: string (nullable = true)
#  |-- quantidade: long (nullable = false)
#
# CPU times: user 1.53 ms, sys: 1.9 ms, total: 3.42 ms
# Wall time: 65.2 ms

# %%
# %%time
df.write.format('delta').mode('append').save(gold_table)
# Out:
# CPU times: user 35.7 ms, sys: 23.4 ms, total: 59.1 ms
# Wall time: 5min 55s

# %% [markdown]
# ### Ler e gravar o DF no Yugabyte

# %%
# df_gold = (spark.read
#     .format('delta')
#     .load(gold_table)
#     .where('ano = 2020')
#     .withColumn('data_base', concat_ws('-', col('ano'), col('mes'), col('dia')))
#     .withColumn('hora_base', concat_ws(':', col('hora'), col('minuto')))
#     .withColumn('horario', concat_ws(' ', col('data_base'), col('hora_base')))
#     .withColumn('horario', to_timestamp('horario'))
#     .drop('data_base')
#     .drop('hora_base')
# )
# df_gold.count()
# df_gold.printSchema()
# df_gold.select('data_base', 'hora_base', 'horario').limit(10).toPandas()

# %%
# (df_gold.write
#  .mode('append')
#  .format('jdbc')
#  .option("url", "jdbc:postgresql://20.201.79.89:5433/amnis")
#  .option("driver", "org.postgresql.Driver")
#  .option("dbtable", "eventos")
#  .option("user", "admin")
#  .option("password", "Zaq12wsX")
#  .save()
# )

# %%
for ano in [2020, 2021, 2022]:
    for mes in range(1,13):
        print(f'Processando {mes}/{ano}')
        gravou = False
        for dia in range(1,32):
            df_gold = (spark.read
                .format('delta')
                .load(gold_table)
                .where(f'ano = {ano} and mes = {mes} and dia = {dia}')
                .withColumn('data_base', concat_ws('-', col('ano'), col('mes'), col('dia')))
                .withColumn('hora_base', concat_ws(':', col('hora'), col('minuto')))
                .withColumn('horario', concat_ws(' ', col('data_base'), col('hora_base')))
                .withColumn('horario', to_timestamp('horario'))
                .drop('data_base')
                .drop('hora_base')
            )

            registros = df_gold.count()

            if registros > 0:
                gravou = True
                print(f'  {dia} gravar {registros} registros')
                (df_gold.write
                 .mode('append')
                 .format('jdbc')
                 .option("url", "jdbc:postgresql://20.201.79.89:5433/amnis")
                 .option("driver", "org.postgresql.Driver")
                 .option("dbtable", "eventos")
                 .option("user", "admin")
                 .option("password", "Zaq12wsX")
                 .save()
                ) 
        if gravou:
            time.sleep(60)
# Out:
# Processando 1/2020
# Processando 2/2020
#   27 gravar 15 registros
#   28 gravar 21 registros
#   29 gravar 15 registros
# Processando 3/2020
#   2 gravar 32 registros
#   3 gravar 24 registros
#   4 gravar 31 registros
#   5 gravar 29 registros
#   6 gravar 6 registros
#   7 gravar 16 registros
#   9 gravar 36 registros
#   10 gravar 41 registros
#   11 gravar 23 registros
#   12 gravar 82 registros
#   13 gravar 37 registros
#   15 gravar 1 registros
#   16 gravar 49 registros
#   17 gravar 24 registros
#   18 gravar 27 registros
#   19 gravar 11 registros
#   20 gravar 41 registros
#   21 gravar 21 registros
#   23 gravar 50 registros
#   24 gravar 28 registros
#   25 gravar 11 registros
#   26 gravar 21 registros
#   27 gravar 17 registros
#   30 gravar 153 registros
#   31 gravar 90 registros
# Processando 4/2020
#   1 gravar 49 registros
#   2 gravar 41 registros
#   3 gravar 6 registros
#   4 gravar 3 registros
#   6 gravar 24 registros
#   7 gravar 10 registros
#   8 gravar 77 registros
#   9 gravar 68 registros
#   10 gravar 27 registros
#   12 gravar 9 registros
#   13 gravar 22 registros
#   14 gravar 88 registros
#   15 gravar 74 registros
#   16 gravar 44 registros
#   17 gravar 76 registros
#   18 gravar 28 registros
#   19 gravar 18 registros
#   20 gravar 91 registros
#   21 gravar 9 registros
#   22 gravar 132 registros
#   23 gravar 428 registros
#   24 gravar 164 registros
#   25 gravar 18 registros
#   26 gravar 1 registros
#   27 gravar 45 registros
#   28 gravar 69 registros
#   29 gravar 36 registros
#   30 gravar 52 registros
# Processando 5/2020
#   1 gravar 38 registros
#   2 gravar 5 registros
#   4 gravar 49 registros
#   5 gravar 72 registros
#   6 gravar 51 registros
#   7 gravar 9 registros
#   8 gravar 35 registros
#   9 gravar 33 registros
#   11 gravar 112 registros
#   12 gravar 32 registros
#   13 gravar 68 registros
#   14 gravar 114 registros
#   15 gravar 40 registros
#   16 gravar 2 registros
#   17 gravar 15 registros
#   18 gravar 54 registros
#   19 gravar 51 registros
#   20 gravar 23 registros
#   21 gravar 42 registros
#   22 gravar 21 registros
#   23 gravar 19 registros
#   24 gravar 37 registros
#   25 gravar 52 registros
#   26 gravar 88 registros
#   27 gravar 102 registros
#   28 gravar 150 registros
#   29 gravar 61 registros
#   30 gravar 273 registros
#   31 gravar 1035 registros
# Processando 6/2020
#   1 gravar 351 registros
#   2 gravar 337 registros
#   3 gravar 1194 registros
#   4 gravar 517 registros
#   5 gravar 102 registros
#   6 gravar 229 registros
#   8 gravar 254 registros
#   9 gravar 1105 registros
#   10 gravar 966 registros
#   11 gravar 115 registros
#   12 gravar 104 registros
#   13 gravar 66 registros
#   15 gravar 61 registros
#   16 gravar 76 registros
#   17 gravar 53 registros
#   18 gravar 62 registros
#   19 gravar 13 registros
#   22 gravar 36 registros
#   23 gravar 140 registros
#   24 gravar 165 registros
#   25 gravar 37 registros
#   26 gravar 57 registros
#   29 gravar 30 registros
#   30 gravar 24 registros
# Processando 7/2020
#   1 gravar 25 registros
#   2 gravar 81 registros
#   3 gravar 82 registros
#   4 gravar 15 registros
#   5 gravar 10 registros
#   6 gravar 93 registros
#   7 gravar 63 registros
#   8 gravar 109 registros
#   9 gravar 5 registros
#   10 gravar 48 registros
#   13 gravar 79 registros
#   14 gravar 35 registros
#   15 gravar 59 registros
#   16 gravar 93 registros
#   17 gravar 209 registros
#   18 gravar 192 registros
#   19 gravar 248 registros
#   20 gravar 56 registros
#   21 gravar 18 registros
#   22 gravar 35 registros
#   23 gravar 193 registros
#   24 gravar 32 registros
#   25 gravar 2 registros
#   26 gravar 2 registros
#   27 gravar 78 registros
#   28 gravar 69 registros
#   29 gravar 20 registros
#   30 gravar 126 registros
#   31 gravar 875 registros
# Processando 8/2020
#   1 gravar 63 registros
#   2 gravar 49 registros
#   3 gravar 529 registros
#   4 gravar 263 registros
#   5 gravar 661 registros
#   6 gravar 634 registros
#   7 gravar 622 registros
#   8 gravar 980 registros
#   9 gravar 558 registros
#   10 gravar 1393 registros
#   11 gravar 1431 registros
#   12 gravar 1468 registros
#   13 gravar 1178 registros
#   14 gravar 1591 registros
#   15 gravar 423 registros
#   16 gravar 106 registros
#   17 gravar 1402 registros
#   18 gravar 1557 registros
#   19 gravar 1460 registros
#   20 gravar 1021 registros
#   21 gravar 994 registros
#   22 gravar 397 registros
#   23 gravar 6 registros
#   24 gravar 1089 registros
#   25 gravar 1546 registros
#   26 gravar 1329 registros
#   27 gravar 1264 registros
#   28 gravar 904 registros
#   29 gravar 67 registros
#   31 gravar 294 registros
# Processando 9/2020
#   1 gravar 1012 registros
#   2 gravar 1161 registros
#   3 gravar 541 registros
#   4 gravar 1198 registros
#   5 gravar 485 registros
#   6 gravar 388 registros
#   7 gravar 765 registros
#   8 gravar 1208 registros
#   9 gravar 1542 registros
#   10 gravar 1434 registros
#   11 gravar 1329 registros
#   12 gravar 490 registros
#   13 gravar 92 registros
#   14 gravar 1170 registros
#   15 gravar 1325 registros
#   16 gravar 1257 registros
#   17 gravar 1797 registros
#   18 gravar 1360 registros
#   19 gravar 501 registros
#   20 gravar 176 registros
#   21 gravar 1352 registros
#   22 gravar 894 registros
#   23 gravar 1432 registros
#   24 gravar 1754 registros
#   25 gravar 1841 registros
#   26 gravar 593 registros
#   27 gravar 87 registros
#   28 gravar 1733 registros
#   29 gravar 2111 registros
#   30 gravar 1858 registros
# Processando 10/2020
#   1 gravar 1952 registros
#   2 gravar 2009 registros
#   3 gravar 477 registros
#   4 gravar 186 registros
#   5 gravar 2037 registros
#   6 gravar 1641 registros
#   7 gravar 1837 registros
#   8 gravar 1858 registros
#   9 gravar 1839 registros
#   10 gravar 466 registros
#   11 gravar 186 registros
#   12 gravar 345 registros
#   13 gravar 1904 registros
#   14 gravar 1806 registros
#   15 gravar 1765 registros
#   16 gravar 1888 registros
#   17 gravar 443 registros
#   18 gravar 62 registros
#   19 gravar 1951 registros
#   20 gravar 1867 registros
#   21 gravar 1288 registros
#   22 gravar 2171 registros
#   23 gravar 1783 registros
#   24 gravar 206 registros
#   25 gravar 156 registros
#   26 gravar 1308 registros
#   27 gravar 1507 registros
#   28 gravar 1278 registros
#   29 gravar 1305 registros
#   30 gravar 1046 registros
#   31 gravar 305 registros
# Processando 11/2020
#   1 gravar 50 registros
#   2 gravar 156 registros
#   3 gravar 1309 registros
#   4 gravar 87 registros
#   5 gravar 6 registros
#   6 gravar 1830 registros
#   7 gravar 325 registros
#   8 gravar 106 registros
#   9 gravar 1608 registros
#   10 gravar 1514 registros
#   11 gravar 1303 registros
#   12 gravar 1148 registros
#   13 gravar 1239 registros
#   14 gravar 284 registros
#   15 gravar 43 registros
#   16 gravar 1457 registros
#   17 gravar 1382 registros
#   18 gravar 1083 registros
#   19 gravar 1355 registros
#   20 gravar 1672 registros
#   21 gravar 587 registros
#   22 gravar 128 registros
#   23 gravar 1555 registros
#   24 gravar 1950 registros
#   25 gravar 1693 registros
#   26 gravar 1705 registros
#   27 gravar 1475 registros
#   28 gravar 1013 registros
#   29 gravar 462 registros
#   30 gravar 1644 registros
# Processando 12/2020
#   1 gravar 2091 registros
#   2 gravar 1645 registros
#   3 gravar 1338 registros
#   4 gravar 1534 registros
#   5 gravar 462 registros
#   6 gravar 136 registros
#   7 gravar 19 registros
#   8 gravar 1795 registros
#   9 gravar 1727 registros
#   10 gravar 1503 registros
#   11 gravar 1729 registros
#   12 gravar 415 registros
#   13 gravar 39 registros
#   14 gravar 1414 registros
#   15 gravar 1364 registros
#   16 gravar 1334 registros
#   17 gravar 1982 registros
#   18 gravar 1556 registros
#   19 gravar 433 registros
#   20 gravar 31 registros
#   21 gravar 695 registros
#   22 gravar 1606 registros
#   23 gravar 1192 registros
#   24 gravar 478 registros
#   28 gravar 16 registros
#   29 gravar 39 registros
#   30 gravar 2070 registros
#   31 gravar 336 registros
# Processando 1/2021
#   1 gravar 2 registros
#   2 gravar 27 registros
#   3 gravar 60 registros
#   4 gravar 1853 registros
#   5 gravar 1801 registros
#   6 gravar 1473 registros
#   7 gravar 1106 registros
#   8 gravar 1283 registros
#   9 gravar 291 registros
#   10 gravar 20 registros
#   11 gravar 1106 registros
#   12 gravar 1565 registros
#   13 gravar 1842 registros
#   14 gravar 2092 registros
#   15 gravar 2508 registros
#   16 gravar 358 registros
#   17 gravar 10 registros
#   18 gravar 1562 registros
#   19 gravar 1399 registros
#   20 gravar 1714 registros
#   21 gravar 1489 registros
#   22 gravar 1497 registros
#   23 gravar 226 registros
#   24 gravar 64 registros
#   25 gravar 1090 registros
#   26 gravar 1215 registros
#   27 gravar 1261 registros
#   28 gravar 1624 registros
#   29 gravar 1526 registros
#   30 gravar 537 registros
#   31 gravar 43 registros
# Processando 2/2021
#   1 gravar 1213 registros
#   2 gravar 1303 registros
#   3 gravar 1866 registros
#   4 gravar 1559 registros
#   5 gravar 1686 registros
#   6 gravar 112 registros
#   7 gravar 31 registros
#   8 gravar 1574 registros
#   9 gravar 1179 registros
#   10 gravar 1982 registros
#   11 gravar 1657 registros
#   12 gravar 2431 registros
#   13 gravar 674 registros
#   14 gravar 16 registros
#   15 gravar 1180 registros
#   16 gravar 1149 registros
#   17 gravar 2031 registros
#   18 gravar 1907 registros
#   19 gravar 2249 registros
#   20 gravar 145 registros
#   22 gravar 981 registros
#   23 gravar 1569 registros
#   24 gravar 1781 registros
#   25 gravar 1367 registros
#   26 gravar 1849 registros
#   27 gravar 357 registros
#   28 gravar 244 registros
# Processando 3/2021
#   1 gravar 1497 registros
#   2 gravar 1904 registros
#   3 gravar 1706 registros
#   4 gravar 1497 registros
#   5 gravar 1521 registros
#   6 gravar 276 registros
#   7 gravar 77 registros
#   8 gravar 1223 registros
#   9 gravar 1472 registros
#   10 gravar 1581 registros
#   11 gravar 1399 registros
#   12 gravar 1172 registros
#   13 gravar 342 registros
#   14 gravar 227 registros
#   15 gravar 2066 registros
#   16 gravar 1792 registros
#   17 gravar 2087 registros
#   18 gravar 1545 registros
#   19 gravar 1668 registros
#   20 gravar 1329 registros
#   21 gravar 197 registros
#   22 gravar 1887 registros
#   23 gravar 2836 registros
#   24 gravar 2374 registros
#   25 gravar 2147 registros
#   26 gravar 1800 registros
#   27 gravar 1702 registros
#   28 gravar 533 registros
#   29 gravar 469 registros
#   30 gravar 381 registros
#   31 gravar 1976 registros
# Processando 4/2021
#   1 gravar 1473 registros
#   2 gravar 91 registros
#   4 gravar 8 registros
#   5 gravar 1573 registros
#   6 gravar 1831 registros
#   7 gravar 2054 registros
#   8 gravar 1984 registros
#   9 gravar 2134 registros
#   10 gravar 883 registros
#   11 gravar 557 registros
#   12 gravar 1486 registros
#   13 gravar 1442 registros
#   14 gravar 1909 registros
#   15 gravar 2427 registros
#   16 gravar 2208 registros
#   17 gravar 1671 registros
#   18 gravar 778 registros
#   19 gravar 2102 registros
#   20 gravar 2501 registros
#   21 gravar 1250 registros
#   22 gravar 2061 registros
#   23 gravar 2251 registros
#   24 gravar 737 registros
#   25 gravar 296 registros
#   26 gravar 2139 registros
#   27 gravar 1728 registros
#   28 gravar 2643 registros
#   29 gravar 2461 registros
#   30 gravar 1867 registros
# Processando 5/2021
#   1 gravar 933 registros
#   2 gravar 516 registros
#   3 gravar 1735 registros
#   4 gravar 1902 registros
#   5 gravar 2218 registros
#   6 gravar 2323 registros
#   7 gravar 2176 registros
#   8 gravar 974 registros
#   9 gravar 362 registros
#   10 gravar 2464 registros
#   11 gravar 2985 registros
#   12 gravar 3239 registros
#   13 gravar 2998 registros
#   14 gravar 3152 registros
#   15 gravar 1299 registros
#   16 gravar 417 registros
#   17 gravar 2530 registros
#   18 gravar 2741 registros
#   19 gravar 2304 registros
#   20 gravar 2689 registros
#   21 gravar 41 registros
#   24 gravar 62 registros
#   25 gravar 155 registros
#   26 gravar 6281 registros
#   27 gravar 2581 registros
#   28 gravar 2680 registros
#   29 gravar 1082 registros
#   30 gravar 379 registros
#   31 gravar 2081 registros
# Processando 6/2021
#   1 gravar 3233 registros
#   2 gravar 3700 registros
#   3 gravar 2223 registros
#   4 gravar 2117 registros
#   5 gravar 1253 registros
#   6 gravar 565 registros
#   7 gravar 2722 registros
#   8 gravar 3107 registros
#   9 gravar 3227 registros
#   10 gravar 3521 registros
#   11 gravar 3308 registros
#   12 gravar 1188 registros
#   13 gravar 662 registros
#   14 gravar 2674 registros
#   15 gravar 266 registros
#   16 gravar 64 registros
#   17 gravar 34 registros
#   18 gravar 33 registros
#   21 gravar 1683 registros
#   22 gravar 7176 registros
#   23 gravar 3356 registros
#   24 gravar 2177 registros
#   25 gravar 3099 registros
#   26 gravar 1637 registros
#   27 gravar 950 registros
#   28 gravar 3174 registros
#   29 gravar 3614 registros
#   30 gravar 3626 registros
# Processando 7/2021
#   1 gravar 3970 registros
#   2 gravar 2288 registros
#   3 gravar 1378 registros
#   4 gravar 1186 registros
#   5 gravar 3108 registros
#   6 gravar 3735 registros
#   7 gravar 3861 registros
#   8 gravar 3402 registros
#   9 gravar 1648 registros
#   10 gravar 1128 registros
#   11 gravar 1376 registros
#   12 gravar 1982 registros
#   13 gravar 3117 registros
#   14 gravar 3338 registros
#   15 gravar 3440 registros
#   16 gravar 3382 registros
#   17 gravar 1081 registros
#   18 gravar 348 registros
#   19 gravar 2388 registros
#   20 gravar 3542 registros
#   21 gravar 2969 registros
#   22 gravar 3276 registros
#   23 gravar 2936 registros
#   24 gravar 958 registros
#   25 gravar 214 registros
#   26 gravar 3506 registros
#   27 gravar 4706 registros
#   28 gravar 4147 registros
#   29 gravar 3250 registros
#   30 gravar 3620 registros
#   31 gravar 809 registros
# Processando 8/2021
#   1 gravar 283 registros
#   2 gravar 2621 registros
#   3 gravar 2733 registros
#   4 gravar 4272 registros
#   5 gravar 2933 registros
#   6 gravar 2885 registros
#   7 gravar 613 registros
#   8 gravar 295 registros
#   9 gravar 3041 registros
#   10 gravar 2552 registros
#   11 gravar 2602 registros
#   12 gravar 2662 registros
#   13 gravar 2539 registros
#   14 gravar 1668 registros
#   15 gravar 333 registros
#   16 gravar 2161 registros
#   17 gravar 3569 registros
#   18 gravar 2827 registros
#   19 gravar 3862 registros
#   20 gravar 2789 registros
#   21 gravar 815 registros
#   22 gravar 701 registros
#   23 gravar 2760 registros
#   24 gravar 4031 registros
#   25 gravar 4232 registros
#   26 gravar 3007 registros
#   27 gravar 2773 registros
#   28 gravar 382 registros
#   29 gravar 704 registros
#   30 gravar 3121 registros
#   31 gravar 3652 registros
# Processando 9/2021
#   1 gravar 32 registros
#   2 gravar 103 registros
#   3 gravar 37 registros
#   4 gravar 7 registros
#   6 gravar 1256 registros
#   7 gravar 4887 registros
#   8 gravar 2276 registros
#   9 gravar 1333 registros
#   10 gravar 1996 registros
#   11 gravar 436 registros
#   12 gravar 1643 registros
#   13 gravar 2112 registros
#   14 gravar 929 registros
#   15 gravar 51 registros
#   16 gravar 44 registros
#   17 gravar 790 registros
#   18 gravar 1679 registros
#   19 gravar 4838 registros
#   20 gravar 204 registros
#   21 gravar 3919 registros
#   22 gravar 3562 registros
#   23 gravar 208 registros
#   24 gravar 2804 registros
#   25 gravar 2289 registros
#   26 gravar 716 registros
#   27 gravar 1570 registros
#   28 gravar 2438 registros
#   29 gravar 2370 registros
#   30 gravar 2553 registros
# Processando 10/2021
#   1 gravar 2334 registros
#   2 gravar 476 registros
#   3 gravar 171 registros
#   4 gravar 1840 registros
#   5 gravar 2735 registros
#   6 gravar 1939 registros
#   7 gravar 1442 registros
#   8 gravar 1882 registros
#   9 gravar 779 registros
#   10 gravar 177 registros
#   11 gravar 2477 registros
#   12 gravar 1570 registros
#   13 gravar 1434 registros
#   14 gravar 1604 registros
#   15 gravar 1551 registros
#   16 gravar 950 registros
#   17 gravar 180 registros
#   18 gravar 1468 registros
#   19 gravar 2381 registros
#   20 gravar 2192 registros
#   21 gravar 376 registros
#   22 gravar 2206 registros
#   23 gravar 435 registros
#   24 gravar 148 registros
#   25 gravar 2141 registros
#   26 gravar 3816 registros
#   27 gravar 3212 registros
#   28 gravar 2078 registros
#   29 gravar 1943 registros
#   30 gravar 487 registros
#   31 gravar 714 registros
# Processando 11/2021
#   1 gravar 3189 registros
#   2 gravar 954 registros
#   3 gravar 1609 registros
#   4 gravar 2463 registros
#   5 gravar 2518 registros
#   6 gravar 1694 registros
#   7 gravar 1349 registros
#   8 gravar 2085 registros
#   9 gravar 2550 registros
#   10 gravar 2487 registros
#   11 gravar 3005 registros
#   12 gravar 2381 registros
#   13 gravar 1610 registros
#   14 gravar 1072 registros
#   15 gravar 1737 registros
#   16 gravar 2060 registros
#   17 gravar 2805 registros
#   18 gravar 2723 registros
#   19 gravar 2661 registros
#   20 gravar 2679 registros
#   21 gravar 1067 registros
#   22 gravar 2836 registros
#   23 gravar 2650 registros
#   24 gravar 2083 registros
#   25 gravar 2542 registros
#   26 gravar 2625 registros
#   27 gravar 948 registros
#   28 gravar 151 registros
#   29 gravar 2235 registros
#   30 gravar 3206 registros
# Processando 12/2021
#   1 gravar 1905 registros
#   2 gravar 2014 registros
#   3 gravar 2104 registros
#   4 gravar 1322 registros
#   5 gravar 230 registros
#   6 gravar 1396 registros
#   7 gravar 1853 registros
#   8 gravar 2476 registros
#   9 gravar 2735 registros
#   10 gravar 1338 registros
#   11 gravar 1081 registros
#   12 gravar 397 registros
#   13 gravar 1653 registros
#   14 gravar 1723 registros
#   15 gravar 1685 registros
#   16 gravar 1998 registros
#   17 gravar 1606 registros
#   18 gravar 336 registros
#   19 gravar 33 registros
#   20 gravar 1355 registros
#   21 gravar 1354 registros
#   22 gravar 2385 registros
#   23 gravar 2252 registros
#   24 gravar 518 registros
#   25 gravar 3 registros
#   26 gravar 47 registros
#   27 gravar 1513 registros
#   28 gravar 2085 registros
#   29 gravar 2759 registros
#   30 gravar 1820 registros
#   31 gravar 248 registros
# Processando 1/2022
#   1 gravar 11 registros
#   2 gravar 40 registros
#   3 gravar 1485 registros
#   4 gravar 1445 registros
#   5 gravar 2499 registros
#   6 gravar 461 registros
#   7 gravar 754 registros
#   9 gravar 27 registros
#   10 gravar 804 registros
#   11 gravar 1257 registros
#   12 gravar 1469 registros
#   13 gravar 1466 registros
#   14 gravar 1397 registros
#   15 gravar 194 registros
#   17 gravar 700 registros
#   18 gravar 705 registros
#   19 gravar 762 registros
#   20 gravar 494 registros
#   21 gravar 763 registros
#   22 gravar 102 registros
#   24 gravar 550 registros
#   25 gravar 1007 registros
#   26 gravar 2040 registros
#   27 gravar 964 registros
#   28 gravar 2174 registros
#   29 gravar 445 registros
#   30 gravar 295 registros
#   31 gravar 1450 registros
# Processando 2/2022
#   1 gravar 960 registros
#   2 gravar 1849 registros
#   3 gravar 2523 registros
#   4 gravar 2304 registros
#   5 gravar 1646 registros
#   6 gravar 16 registros
#   7 gravar 3065 registros
#   8 gravar 2103 registros
#   9 gravar 2051 registros
#   10 gravar 2017 registros
#   11 gravar 1906 registros
#   12 gravar 645 registros
#   13 gravar 57 registros
#   14 gravar 1762 registros
#   15 gravar 2064 registros
#   16 gravar 1773 registros
#   17 gravar 1863 registros
#   18 gravar 1466 registros
#   20 gravar 924 registros
#   21 gravar 2882 registros
#   22 gravar 703 registros
#   23 gravar 7013 registros
#   24 gravar 8289 registros
#   25 gravar 11996 registros
#   26 gravar 844 registros
#   27 gravar 5 registros
#   28 gravar 955 registros
# Processando 3/2022
#   1 gravar 1878 registros
#   2 gravar 3757 registros
#   3 gravar 14062 registros
#   4 gravar 4342 registros
#   5 gravar 36015 registros
#   7 gravar 20174 registros
#   8 gravar 10925 registros
#   9 gravar 6544 registros
#   10 gravar 8470 registros
#   11 gravar 32242 registros
#   12 gravar 375 registros
#   13 gravar 9 registros
#   14 gravar 19404 registros
#   15 gravar 17962 registros
#   16 gravar 19315 registros
#   17 gravar 24883 registros
#   18 gravar 24867 registros
#   19 gravar 5812 registros
#   20 gravar 273 registros
# Processando 4/2022
# Processando 5/2022
# Processando 6/2022
# Processando 7/2022
# Processando 8/2022
# Processando 9/2022
# Processando 10/2022
# Processando 11/2022
# Processando 12/2022
